# %%
import torch
import os
import random
import numpy as np
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt

# %%
def set_seed(seed=1):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
set_seed(1)

# %%
imgpath = "/home/bruce/Downloads/nms.jpg"
img = Image.open(imgpath)
print(img.size)
img
# Out:
# (449, 500)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=449x500 at 0x7F1F80B3B978>

# %% [markdown]
# ### 1. 图像转换

# %%
transform = transforms.Compose([transforms.ToTensor(),  # Convert a ``PIL Image`` or ``numpy.ndarray`` to tensor
                               transforms.ToPILImage()])  # Convert a tensor or an ndarray to PIL Image.
new_img = transform(img)
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=449x500 at 0x7F1F80B3BCC0>

# %%
type(new_img)
# Out:
# PIL.Image.Image

# %%
img.mode
# Out:
# 'RGB'

# %% [markdown]
# ### 2. 图像尺寸定义

# %%
transform = transforms.Compose([transforms.Resize((224, 224)),
                               transforms.ToTensor(),
                               transforms.ToPILImage()])
re_img = transform(img)
print(re_img.size)
re_img
# Out:
# (224, 224)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F1F80B58748>

# %% [markdown]
# ### 3. 图像中心裁剪
